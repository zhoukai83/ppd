# %%
import pandas as pd
from pandas import DataFrame
from IPython.display import display
pd.set_option('display.max_columns', None)

# %%
item = {"listingId": 124795277, "借款用途": "日常消费", "借款金额": "¥18,925", "其他事项": "暂无", "协议利率": "20%",
        "单笔最高借款金额": "¥11,900.00", "历史最高负债": "¥13,151.10", "历史记录": "0次流标， 0次撤标， 0次失败", "学习形式": "无", "工作信息": "私营业主",
        "年龄": "27", "征信记录": "暂未提供", "待还金额": "¥2,112.52", "性别": "女", "成功借款次数": "5次", "成功还款次数": "21次", "收入情况": "暂未提供",
        "文化程度": "无", "期限": "6个月", "正常还清次数": "21次", "毕业院校": "无", "注册时间": "2017/03/14", "第一次成功借款时间": "2017/03/14",
        "累计借款金额": "¥35,708.00", "级别": "B", "网络借贷平台借款余额": "暂未提供", "资金运用情况": "日常消费", "还款来源": "个人存款",
        "逾期（0-15天）还清次数": "0次", "逾期（15天以上）还清次数": "0次"}

# %%
df = pd.read_csv("UI\\UIMain.csv", encoding="utf-8")
display(df)
# Out:
#     Unnamed: 0  listingId  借款用途    借款金额 其他事项 协议利率   单笔最高借款金额     历史最高负债  \
# 0            0  124913347  日常消费     500   暂无  20%   1,000.00   2,166.35
# 1            1  124913372    装修  13,400   暂无  20%  13,000.00  17,676.00
# 2            2  124913984  日常消费  13,157   暂无  20%   8,361.00  24,482.97
# 3            3  124914438  日常消费   1,633   暂无  20%   3,700.00   7,294.50
# 4            4  124914485  日常消费   1,447   暂无  20%   6,242.00  16,633.04
# 5            5  124914495  日常消费  10,394   暂无  20%  15,000.00  20,003.82
# 6            6  124914584  日常消费  10,000   暂无  20%  12,500.00  14,387.19
# 7            7  124914629  日常消费     642   暂无  20%   2,000.00   2,719.92
# 8            8  124914828  日常消费   1,816   暂无  20%  10,000.00  20,351.59
# 9            9  124914976  日常消费   2,600   暂无  20%   7,000.00   8,840.40
# 10          10  124914967    旅游   2,700   暂无  20%   8,500.00  18,517.12
# 11          11  124915226  日常消费   1,817   暂无  20%   5,507.00  10,495.70
# 12          12  124915445  兼职创业   2,000   暂无  20%   4,500.00   7,447.77
# 13          13  124915675  日常消费     985   暂无  20%   3,000.00   4,610.90
# 14          14  124915648    旅游   1,681   暂无  20%   9,718.00  20,572.72
# 15          15  124916059    装修  14,000   暂无  20%   8,000.00   9,143.22
# 16          16  124916107  日常消费   3,700   暂无  20%   3,700.00   4,228.50
# 17          17  124916191    医疗     700   暂无  20%   1,500.00   5,033.82
# 18          18  124916416  日常消费   7,000   暂无  20%  12,000.00  13,477.56
# 19          19  124916488  日常消费   3,000   暂无  20%   3,000.00   3,490.92
# 20          20  124916836  日常消费   2,000   暂无  20%  10,000.00  19,984.07
# 21          21  124917210  日常消费   1,676   暂无  20%  13,060.00  20,825.01
# 22          22  124917260  日常消费   2,000   暂无  20%   5,000.00  12,650.34
#
#                 历史记录  学习形式  工作信息  年龄  征信记录       待还金额 性别 成功借款次数 成功还款次数  收入情况  \
# 0   2次流标， 0次撤标， 0次失败     无  暂未提供  21  暂未提供   1,642.67  男     3次     8次  暂未提供
# 1   0次流标， 1次撤标， 0次失败    普通  暂未提供  26  暂未提供       0.00  男     1次     2次  暂未提供
# 2   0次流标， 0次撤标， 0次失败    普通  暂未提供  28  暂未提供   9,448.40  女    14次    86次  暂未提供
# 3   0次流标， 0次撤标， 0次失败     无  私营业主  22  暂未提供   5,402.43  女    19次    93次  暂未提供
# 4   0次流标， 0次撤标， 0次失败  网络教育  暂未提供  37  暂未提供  15,067.04  男    13次    78次  暂未提供
# 5   2次流标， 2次撤标， 0次失败     无  暂未提供  45  暂未提供  15,443.31  男     3次    12次  暂未提供
# 6   0次流标， 0次撤标， 0次失败    普通  私营业主  35  暂未提供   4,037.44  男    10次    39次  暂未提供
# 7   2次流标， 1次撤标， 0次失败    普通  暂未提供  23  暂未提供   1,772.08  男     1次     4次  暂未提供
# 8   0次流标， 1次撤标， 0次失败     无  暂未提供  27  暂未提供  19,306.45  女    11次    68次  暂未提供
# 9   0次流标， 0次撤标， 0次失败     无  暂未提供  26  暂未提供   6,220.49  女     3次    14次  暂未提供
# 10  0次流标， 0次撤标， 0次失败     无  暂未提供  23  暂未提供  15,215.08  女    10次    62次  暂未提供
# 11  0次流标， 0次撤标， 0次失败     无  暂未提供  21  暂未提供   8,457.76  女    12次    55次  暂未提供
# 12  1次流标， 0次撤标， 0次失败     无  暂未提供  29  暂未提供   5,135.04  女     8次    26次  暂未提供
# 13  0次流标， 1次撤标， 0次失败     无  私营业主  21  暂未提供   3,377.36  男     4次    13次  暂未提供
# 14  0次流标， 0次撤标， 0次失败     无  暂未提供  41  暂未提供  18,047.67  女    12次    78次  暂未提供
# 15  0次流标， 0次撤标， 0次失败  网络教育  私营业主  29  暂未提供       0.00  男     1次     6次  暂未提供
# 16  1次流标， 0次撤标， 0次失败     无  暂未提供  28  暂未提供       0.00  女     2次    13次  暂未提供
# 17  0次流标， 1次撤标， 0次失败     无  暂未提供  19  暂未提供   3,743.90  男    13次    49次  暂未提供
# 18  2次流标， 0次撤标， 0次失败    普通  暂未提供  23  暂未提供   1,735.93  女     6次    35次  暂未提供
# 19  0次流标， 0次撤标， 0次失败    普通  暂未提供  31  暂未提供       0.00  女     2次     7次  暂未提供
# 20  0次流标， 0次撤标， 0次失败     无  私营业主  23  暂未提供  17,323.89  女    14次   100次  暂未提供
# 21  0次流标， 0次撤标， 0次失败     无  私营业主  27  暂未提供  18,652.74  女     6次    30次  暂未提供
# 22  0次流标， 1次撤标， 0次失败     无  暂未提供  27  暂未提供  10,861.13  男    14次    58次  暂未提供
#
#       文化程度   期限 正常还清次数        毕业院校        注册时间   第一次成功借款时间     累计借款金额 级别  \
# 0        无  6个月     8次           无  2018/01/17  2018/05/04   2,000.00  B
# 1       本科  6个月     2次  郑州航空工业管理学院  2018/01/22  2018/01/29  13,000.00  B
# 2       专科  6个月    80次    德州科技职业学院  2016/10/24  2016/10/25  53,325.00  B
# 3        无  6个月    89次           无  2017/02/10  2017/02/10  30,947.00  B
# 4       专科  6个月    76次        同济大学  2017/03/11  2017/03/11  41,120.00  B
# 5        无  6个月    12次           无  2016/11/17  2017/10/31  26,700.00  B
# 6       专科  3个月    37次  南通纺织职业技术学院  2017/06/27  2017/07/28  45,500.00  B
# 7       本科  6个月     4次        青海大学  2017/11/25  2018/05/04   2,000.00  B
# 8        无  6个月    68次           无  2016/10/31  2016/11/09  50,990.00  B
# 9        无  3个月    12次           无  2017/07/17  2017/07/17  13,500.00  B
# 10       无  6个月    62次           无  2016/10/07  2016/10/10  43,496.00  B
# 11       无  6个月    53次           无  2016/04/14  2017/07/02  23,761.00  B
# 12       无  6个月    26次           无  2017/01/19  2017/11/21  15,300.00  B
# 13       无  3个月    13次           无  2018/02/08  2018/02/10   5,850.00  B
# 14       无  6个月    78次           无  2016/11/14  2016/11/14  51,959.00  B
# 15      专科  6个月     6次      西南交通大学  2017/11/17  2017/11/17   8,000.00  B
# 16       无  6个月    13次           无  2018/03/03  2018/03/03   5,500.00  B
# 17       无  6个月    47次           无  2017/10/30  2017/11/07   9,900.00  B
# 18      本科  3个月    21次      中央财经大学  2017/05/12  2017/05/13  30,597.00  B
# 19  专科(高职)  3个月     6次    山西工商职业学院  2018/03/15  2018/03/15   6,000.00  B
# 20       无  3个月    97次           无  2017/01/16  2017/01/21  39,207.00  B
# 21       无  6个月    30次           无  2017/04/24  2017/04/24  36,451.00  B
# 22       无  6个月    58次           无  2016/09/05  2016/09/05  38,100.00  B
#
#     网络借贷平台借款余额 资金运用情况  还款来源 逾期（0-15天）还清次数 逾期（15天以上）还清次数
# 0         暂未提供   日常消费  个人存款            0次            0次
# 1         暂未提供     装修  个人存款            0次            0次
# 2   108,380.00   日常消费  薪资收入            6次            0次
# 3         暂未提供   日常消费  薪资收入            4次            0次
# 4         暂未提供   日常消费  个人存款            2次            0次
# 5         暂未提供   日常消费  薪资收入            0次            0次
# 6         暂未提供   日常消费  个人存款            2次            0次
# 7         暂未提供   日常消费  薪资收入            0次            0次
# 8         暂未提供   日常消费  薪资收入            0次            0次
# 9         暂未提供   日常消费  薪资收入            2次            0次
# 10        暂未提供     旅游  经营收入            0次            0次
# 11        暂未提供   日常消费  薪资收入            2次            0次
# 12    4,500.00   兼职创业  投资收入            0次            0次
# 13        暂未提供   日常消费  薪资收入            0次            0次
# 14      420.00     旅游  薪资收入            0次            0次
# 15        暂未提供     装修  经营收入            0次            0次
# 16        暂未提供   日常消费  个人存款            0次            0次
# 17        暂未提供     医疗  薪资收入            2次            0次
# 18        暂未提供   日常消费  薪资收入           11次            0次
# 19        暂未提供   日常消费  薪资收入            1次            0次
# 20        暂未提供   日常消费  薪资收入            3次            0次
# 21        暂未提供   日常消费  经营收入            0次            0次
# 22        暂未提供   日常消费  薪资收入            0次            0次
# [{'Unnamed: 0': 0,
#   'listingId': 124913347,
#   '借款用途': '日常消费',
#   '借款金额': '500',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '1,000.00',
#   '历史最高负债': '2,166.35',
#   '历史记录': '2次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 21,
#   '征信记录': '暂未提供',
#   '待还金额': '1,642.67',
#   '性别': '男',
#   '成功借款次数': '3次',
#   '成功还款次数': '8次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '8次',
#   '毕业院校': '无',
#   '注册时间': '2018/01/17',
#   '第一次成功借款时间': '2018/05/04',
#   '累计借款金额': '2,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 1,
#   'listingId': 124913372,
#   '借款用途': '装修',
#   '借款金额': '13,400',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '13,000.00',
#   '历史最高负债': '17,676.00',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 26,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '男',
#   '成功借款次数': '1次',
#   '成功还款次数': '2次',
#   '收入情况': '暂未提供',
#   '文化程度': '本科',
#   '期限': '6个月',
#   '正常还清次数': '2次',
#   '毕业院校': '郑州航空工业管理学院',
#   '注册时间': '2018/01/22',
#   '第一次成功借款时间': '2018/01/29',
#   '累计借款金额': '13,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '装修',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 2,
#   'listingId': 124913984,
#   '借款用途': '日常消费',
#   '借款金额': '13,157',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '8,361.00',
#   '历史最高负债': '24,482.97',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 28,
#   '征信记录': '暂未提供',
#   '待还金额': '9,448.40',
#   '性别': '女',
#   '成功借款次数': '14次',
#   '成功还款次数': '86次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '6个月',
#   '正常还清次数': '80次',
#   '毕业院校': '德州科技职业学院',
#   '注册时间': '2016/10/24',
#   '第一次成功借款时间': '2016/10/25',
#   '累计借款金额': '53,325.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '108,380.00',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '6次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 3,
#   'listingId': 124914438,
#   '借款用途': '日常消费',
#   '借款金额': '1,633',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,700.00',
#   '历史最高负债': '7,294.50',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 22,
#   '征信记录': '暂未提供',
#   '待还金额': '5,402.43',
#   '性别': '女',
#   '成功借款次数': '19次',
#   '成功还款次数': '93次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '89次',
#   '毕业院校': '无',
#   '注册时间': '2017/02/10',
#   '第一次成功借款时间': '2017/02/10',
#   '累计借款金额': '30,947.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '4次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 4,
#   'listingId': 124914485,
#   '借款用途': '日常消费',
#   '借款金额': '1,447',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '6,242.00',
#   '历史最高负债': '16,633.04',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '网络教育',
#   '工作信息': '暂未提供',
#   '年龄': 37,
#   '征信记录': '暂未提供',
#   '待还金额': '15,067.04',
#   '性别': '男',
#   '成功借款次数': '13次',
#   '成功还款次数': '78次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '6个月',
#   '正常还清次数': '76次',
#   '毕业院校': '同济大学',
#   '注册时间': '2017/03/11',
#   '第一次成功借款时间': '2017/03/11',
#   '累计借款金额': '41,120.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 5,
#   'listingId': 124914495,
#   '借款用途': '日常消费',
#   '借款金额': '10,394',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '15,000.00',
#   '历史最高负债': '20,003.82',
#   '历史记录': '2次流标， 2次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 45,
#   '征信记录': '暂未提供',
#   '待还金额': '15,443.31',
#   '性别': '男',
#   '成功借款次数': '3次',
#   '成功还款次数': '12次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '12次',
#   '毕业院校': '无',
#   '注册时间': '2016/11/17',
#   '第一次成功借款时间': '2017/10/31',
#   '累计借款金额': '26,700.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 6,
#   'listingId': 124914584,
#   '借款用途': '日常消费',
#   '借款金额': '10,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '12,500.00',
#   '历史最高负债': '14,387.19',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '私营业主',
#   '年龄': 35,
#   '征信记录': '暂未提供',
#   '待还金额': '4,037.44',
#   '性别': '男',
#   '成功借款次数': '10次',
#   '成功还款次数': '39次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '3个月',
#   '正常还清次数': '37次',
#   '毕业院校': '南通纺织职业技术学院',
#   '注册时间': '2017/06/27',
#   '第一次成功借款时间': '2017/07/28',
#   '累计借款金额': '45,500.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 7,
#   'listingId': 124914629,
#   '借款用途': '日常消费',
#   '借款金额': '642',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '2,000.00',
#   '历史最高负债': '2,719.92',
#   '历史记录': '2次流标， 1次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '1,772.08',
#   '性别': '男',
#   '成功借款次数': '1次',
#   '成功还款次数': '4次',
#   '收入情况': '暂未提供',
#   '文化程度': '本科',
#   '期限': '6个月',
#   '正常还清次数': '4次',
#   '毕业院校': '青海大学',
#   '注册时间': '2017/11/25',
#   '第一次成功借款时间': '2018/05/04',
#   '累计借款金额': '2,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 8,
#   'listingId': 124914828,
#   '借款用途': '日常消费',
#   '借款金额': '1,816',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '10,000.00',
#   '历史最高负债': '20,351.59',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 27,
#   '征信记录': '暂未提供',
#   '待还金额': '19,306.45',
#   '性别': '女',
#   '成功借款次数': '11次',
#   '成功还款次数': '68次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '68次',
#   '毕业院校': '无',
#   '注册时间': '2016/10/31',
#   '第一次成功借款时间': '2016/11/09',
#   '累计借款金额': '50,990.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 9,
#   'listingId': 124914976,
#   '借款用途': '日常消费',
#   '借款金额': '2,600',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '7,000.00',
#   '历史最高负债': '8,840.40',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 26,
#   '征信记录': '暂未提供',
#   '待还金额': '6,220.49',
#   '性别': '女',
#   '成功借款次数': '3次',
#   '成功还款次数': '14次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '3个月',
#   '正常还清次数': '12次',
#   '毕业院校': '无',
#   '注册时间': '2017/07/17',
#   '第一次成功借款时间': '2017/07/17',
#   '累计借款金额': '13,500.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 10,
#   'listingId': 124914967,
#   '借款用途': '旅游',
#   '借款金额': '2,700',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '8,500.00',
#   '历史最高负债': '18,517.12',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '15,215.08',
#   '性别': '女',
#   '成功借款次数': '10次',
#   '成功还款次数': '62次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '62次',
#   '毕业院校': '无',
#   '注册时间': '2016/10/07',
#   '第一次成功借款时间': '2016/10/10',
#   '累计借款金额': '43,496.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '旅游',
#   '还款来源': '经营收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 11,
#   'listingId': 124915226,
#   '借款用途': '日常消费',
#   '借款金额': '1,817',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '5,507.00',
#   '历史最高负债': '10,495.70',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 21,
#   '征信记录': '暂未提供',
#   '待还金额': '8,457.76',
#   '性别': '女',
#   '成功借款次数': '12次',
#   '成功还款次数': '55次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '53次',
#   '毕业院校': '无',
#   '注册时间': '2016/04/14',
#   '第一次成功借款时间': '2017/07/02',
#   '累计借款金额': '23,761.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 12,
#   'listingId': 124915445,
#   '借款用途': '兼职创业',
#   '借款金额': '2,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '4,500.00',
#   '历史最高负债': '7,447.77',
#   '历史记录': '1次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 29,
#   '征信记录': '暂未提供',
#   '待还金额': '5,135.04',
#   '性别': '女',
#   '成功借款次数': '8次',
#   '成功还款次数': '26次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '26次',
#   '毕业院校': '无',
#   '注册时间': '2017/01/19',
#   '第一次成功借款时间': '2017/11/21',
#   '累计借款金额': '15,300.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '4,500.00',
#   '资金运用情况': '兼职创业',
#   '还款来源': '投资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 13,
#   'listingId': 124915675,
#   '借款用途': '日常消费',
#   '借款金额': '985',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,000.00',
#   '历史最高负债': '4,610.90',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 21,
#   '征信记录': '暂未提供',
#   '待还金额': '3,377.36',
#   '性别': '男',
#   '成功借款次数': '4次',
#   '成功还款次数': '13次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '3个月',
#   '正常还清次数': '13次',
#   '毕业院校': '无',
#   '注册时间': '2018/02/08',
#   '第一次成功借款时间': '2018/02/10',
#   '累计借款金额': '5,850.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 14,
#   'listingId': 124915648,
#   '借款用途': '旅游',
#   '借款金额': '1,681',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '9,718.00',
#   '历史最高负债': '20,572.72',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 41,
#   '征信记录': '暂未提供',
#   '待还金额': '18,047.67',
#   '性别': '女',
#   '成功借款次数': '12次',
#   '成功还款次数': '78次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '78次',
#   '毕业院校': '无',
#   '注册时间': '2016/11/14',
#   '第一次成功借款时间': '2016/11/14',
#   '累计借款金额': '51,959.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '420.00',
#   '资金运用情况': '旅游',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 15,
#   'listingId': 124916059,
#   '借款用途': '装修',
#   '借款金额': '14,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '8,000.00',
#   '历史最高负债': '9,143.22',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '网络教育',
#   '工作信息': '私营业主',
#   '年龄': 29,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '男',
#   '成功借款次数': '1次',
#   '成功还款次数': '6次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '6个月',
#   '正常还清次数': '6次',
#   '毕业院校': '西南交通大学',
#   '注册时间': '2017/11/17',
#   '第一次成功借款时间': '2017/11/17',
#   '累计借款金额': '8,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '装修',
#   '还款来源': '经营收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 16,
#   'listingId': 124916107,
#   '借款用途': '日常消费',
#   '借款金额': '3,700',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,700.00',
#   '历史最高负债': '4,228.50',
#   '历史记录': '1次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 28,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '女',
#   '成功借款次数': '2次',
#   '成功还款次数': '13次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '13次',
#   '毕业院校': '无',
#   '注册时间': '2018/03/03',
#   '第一次成功借款时间': '2018/03/03',
#   '累计借款金额': '5,500.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 17,
#   'listingId': 124916191,
#   '借款用途': '医疗',
#   '借款金额': '700',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '1,500.00',
#   '历史最高负债': '5,033.82',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 19,
#   '征信记录': '暂未提供',
#   '待还金额': '3,743.90',
#   '性别': '男',
#   '成功借款次数': '13次',
#   '成功还款次数': '49次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '47次',
#   '毕业院校': '无',
#   '注册时间': '2017/10/30',
#   '第一次成功借款时间': '2017/11/07',
#   '累计借款金额': '9,900.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '医疗',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 18,
#   'listingId': 124916416,
#   '借款用途': '日常消费',
#   '借款金额': '7,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '12,000.00',
#   '历史最高负债': '13,477.56',
#   '历史记录': '2次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '1,735.93',
#   '性别': '女',
#   '成功借款次数': '6次',
#   '成功还款次数': '35次',
#   '收入情况': '暂未提供',
#   '文化程度': '本科',
#   '期限': '3个月',
#   '正常还清次数': '21次',
#   '毕业院校': '中央财经大学',
#   '注册时间': '2017/05/12',
#   '第一次成功借款时间': '2017/05/13',
#   '累计借款金额': '30,597.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '11次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 19,
#   'listingId': 124916488,
#   '借款用途': '日常消费',
#   '借款金额': '3,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,000.00',
#   '历史最高负债': '3,490.92',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 31,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '女',
#   '成功借款次数': '2次',
#   '成功还款次数': '7次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科(高职)',
#   '期限': '3个月',
#   '正常还清次数': '6次',
#   '毕业院校': '山西工商职业学院',
#   '注册时间': '2018/03/15',
#   '第一次成功借款时间': '2018/03/15',
#   '累计借款金额': '6,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '1次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 20,
#   'listingId': 124916836,
#   '借款用途': '日常消费',
#   '借款金额': '2,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '10,000.00',
#   '历史最高负债': '19,984.07',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '17,323.89',
#   '性别': '女',
#   '成功借款次数': '14次',
#   '成功还款次数': '100次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '3个月',
#   '正常还清次数': '97次',
#   '毕业院校': '无',
#   '注册时间': '2017/01/16',
#   '第一次成功借款时间': '2017/01/21',
#   '累计借款金额': '39,207.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '3次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 21,
#   'listingId': 124917210,
#   '借款用途': '日常消费',
#   '借款金额': '1,676',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '13,060.00',
#   '历史最高负债': '20,825.01',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 27,
#   '征信记录': '暂未提供',
#   '待还金额': '18,652.74',
#   '性别': '女',
#   '成功借款次数': '6次',
#   '成功还款次数': '30次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '30次',
#   '毕业院校': '无',
#   '注册时间': '2017/04/24',
#   '第一次成功借款时间': '2017/04/24',
#   '累计借款金额': '36,451.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '经营收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 22,
#   'listingId': 124917260,
#   '借款用途': '日常消费',
#   '借款金额': '2,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '5,000.00',
#   '历史最高负债': '12,650.34',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 27,
#   '征信记录': '暂未提供',
#   '待还金额': '10,861.13',
#   '性别': '男',
#   '成功借款次数': '14次',
#   '成功还款次数': '58次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '58次',
#   '毕业院校': '无',
#   '注册时间': '2016/09/05',
#   '第一次成功借款时间': '2016/09/05',
#   '累计借款金额': '38,100.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'}]

# %%
df.to_dict('records')
# Out:
# [{'Unnamed: 0': 0,
#   'listingId': 124913347,
#   '借款用途': '日常消费',
#   '借款金额': '500',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '1,000.00',
#   '历史最高负债': '2,166.35',
#   '历史记录': '2次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 21,
#   '征信记录': '暂未提供',
#   '待还金额': '1,642.67',
#   '性别': '男',
#   '成功借款次数': '3次',
#   '成功还款次数': '8次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '8次',
#   '毕业院校': '无',
#   '注册时间': '2018/01/17',
#   '第一次成功借款时间': '2018/05/04',
#   '累计借款金额': '2,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 1,
#   'listingId': 124913372,
#   '借款用途': '装修',
#   '借款金额': '13,400',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '13,000.00',
#   '历史最高负债': '17,676.00',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 26,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '男',
#   '成功借款次数': '1次',
#   '成功还款次数': '2次',
#   '收入情况': '暂未提供',
#   '文化程度': '本科',
#   '期限': '6个月',
#   '正常还清次数': '2次',
#   '毕业院校': '郑州航空工业管理学院',
#   '注册时间': '2018/01/22',
#   '第一次成功借款时间': '2018/01/29',
#   '累计借款金额': '13,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '装修',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 2,
#   'listingId': 124913984,
#   '借款用途': '日常消费',
#   '借款金额': '13,157',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '8,361.00',
#   '历史最高负债': '24,482.97',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 28,
#   '征信记录': '暂未提供',
#   '待还金额': '9,448.40',
#   '性别': '女',
#   '成功借款次数': '14次',
#   '成功还款次数': '86次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '6个月',
#   '正常还清次数': '80次',
#   '毕业院校': '德州科技职业学院',
#   '注册时间': '2016/10/24',
#   '第一次成功借款时间': '2016/10/25',
#   '累计借款金额': '53,325.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '108,380.00',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '6次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 3,
#   'listingId': 124914438,
#   '借款用途': '日常消费',
#   '借款金额': '1,633',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,700.00',
#   '历史最高负债': '7,294.50',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 22,
#   '征信记录': '暂未提供',
#   '待还金额': '5,402.43',
#   '性别': '女',
#   '成功借款次数': '19次',
#   '成功还款次数': '93次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '89次',
#   '毕业院校': '无',
#   '注册时间': '2017/02/10',
#   '第一次成功借款时间': '2017/02/10',
#   '累计借款金额': '30,947.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '4次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 4,
#   'listingId': 124914485,
#   '借款用途': '日常消费',
#   '借款金额': '1,447',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '6,242.00',
#   '历史最高负债': '16,633.04',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '网络教育',
#   '工作信息': '暂未提供',
#   '年龄': 37,
#   '征信记录': '暂未提供',
#   '待还金额': '15,067.04',
#   '性别': '男',
#   '成功借款次数': '13次',
#   '成功还款次数': '78次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '6个月',
#   '正常还清次数': '76次',
#   '毕业院校': '同济大学',
#   '注册时间': '2017/03/11',
#   '第一次成功借款时间': '2017/03/11',
#   '累计借款金额': '41,120.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 5,
#   'listingId': 124914495,
#   '借款用途': '日常消费',
#   '借款金额': '10,394',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '15,000.00',
#   '历史最高负债': '20,003.82',
#   '历史记录': '2次流标， 2次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 45,
#   '征信记录': '暂未提供',
#   '待还金额': '15,443.31',
#   '性别': '男',
#   '成功借款次数': '3次',
#   '成功还款次数': '12次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '12次',
#   '毕业院校': '无',
#   '注册时间': '2016/11/17',
#   '第一次成功借款时间': '2017/10/31',
#   '累计借款金额': '26,700.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 6,
#   'listingId': 124914584,
#   '借款用途': '日常消费',
#   '借款金额': '10,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '12,500.00',
#   '历史最高负债': '14,387.19',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '私营业主',
#   '年龄': 35,
#   '征信记录': '暂未提供',
#   '待还金额': '4,037.44',
#   '性别': '男',
#   '成功借款次数': '10次',
#   '成功还款次数': '39次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '3个月',
#   '正常还清次数': '37次',
#   '毕业院校': '南通纺织职业技术学院',
#   '注册时间': '2017/06/27',
#   '第一次成功借款时间': '2017/07/28',
#   '累计借款金额': '45,500.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 7,
#   'listingId': 124914629,
#   '借款用途': '日常消费',
#   '借款金额': '642',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '2,000.00',
#   '历史最高负债': '2,719.92',
#   '历史记录': '2次流标， 1次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '1,772.08',
#   '性别': '男',
#   '成功借款次数': '1次',
#   '成功还款次数': '4次',
#   '收入情况': '暂未提供',
#   '文化程度': '本科',
#   '期限': '6个月',
#   '正常还清次数': '4次',
#   '毕业院校': '青海大学',
#   '注册时间': '2017/11/25',
#   '第一次成功借款时间': '2018/05/04',
#   '累计借款金额': '2,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 8,
#   'listingId': 124914828,
#   '借款用途': '日常消费',
#   '借款金额': '1,816',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '10,000.00',
#   '历史最高负债': '20,351.59',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 27,
#   '征信记录': '暂未提供',
#   '待还金额': '19,306.45',
#   '性别': '女',
#   '成功借款次数': '11次',
#   '成功还款次数': '68次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '68次',
#   '毕业院校': '无',
#   '注册时间': '2016/10/31',
#   '第一次成功借款时间': '2016/11/09',
#   '累计借款金额': '50,990.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 9,
#   'listingId': 124914976,
#   '借款用途': '日常消费',
#   '借款金额': '2,600',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '7,000.00',
#   '历史最高负债': '8,840.40',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 26,
#   '征信记录': '暂未提供',
#   '待还金额': '6,220.49',
#   '性别': '女',
#   '成功借款次数': '3次',
#   '成功还款次数': '14次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '3个月',
#   '正常还清次数': '12次',
#   '毕业院校': '无',
#   '注册时间': '2017/07/17',
#   '第一次成功借款时间': '2017/07/17',
#   '累计借款金额': '13,500.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 10,
#   'listingId': 124914967,
#   '借款用途': '旅游',
#   '借款金额': '2,700',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '8,500.00',
#   '历史最高负债': '18,517.12',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '15,215.08',
#   '性别': '女',
#   '成功借款次数': '10次',
#   '成功还款次数': '62次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '62次',
#   '毕业院校': '无',
#   '注册时间': '2016/10/07',
#   '第一次成功借款时间': '2016/10/10',
#   '累计借款金额': '43,496.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '旅游',
#   '还款来源': '经营收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 11,
#   'listingId': 124915226,
#   '借款用途': '日常消费',
#   '借款金额': '1,817',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '5,507.00',
#   '历史最高负债': '10,495.70',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 21,
#   '征信记录': '暂未提供',
#   '待还金额': '8,457.76',
#   '性别': '女',
#   '成功借款次数': '12次',
#   '成功还款次数': '55次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '53次',
#   '毕业院校': '无',
#   '注册时间': '2016/04/14',
#   '第一次成功借款时间': '2017/07/02',
#   '累计借款金额': '23,761.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 12,
#   'listingId': 124915445,
#   '借款用途': '兼职创业',
#   '借款金额': '2,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '4,500.00',
#   '历史最高负债': '7,447.77',
#   '历史记录': '1次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 29,
#   '征信记录': '暂未提供',
#   '待还金额': '5,135.04',
#   '性别': '女',
#   '成功借款次数': '8次',
#   '成功还款次数': '26次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '26次',
#   '毕业院校': '无',
#   '注册时间': '2017/01/19',
#   '第一次成功借款时间': '2017/11/21',
#   '累计借款金额': '15,300.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '4,500.00',
#   '资金运用情况': '兼职创业',
#   '还款来源': '投资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 13,
#   'listingId': 124915675,
#   '借款用途': '日常消费',
#   '借款金额': '985',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,000.00',
#   '历史最高负债': '4,610.90',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 21,
#   '征信记录': '暂未提供',
#   '待还金额': '3,377.36',
#   '性别': '男',
#   '成功借款次数': '4次',
#   '成功还款次数': '13次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '3个月',
#   '正常还清次数': '13次',
#   '毕业院校': '无',
#   '注册时间': '2018/02/08',
#   '第一次成功借款时间': '2018/02/10',
#   '累计借款金额': '5,850.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 14,
#   'listingId': 124915648,
#   '借款用途': '旅游',
#   '借款金额': '1,681',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '9,718.00',
#   '历史最高负债': '20,572.72',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 41,
#   '征信记录': '暂未提供',
#   '待还金额': '18,047.67',
#   '性别': '女',
#   '成功借款次数': '12次',
#   '成功还款次数': '78次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '78次',
#   '毕业院校': '无',
#   '注册时间': '2016/11/14',
#   '第一次成功借款时间': '2016/11/14',
#   '累计借款金额': '51,959.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '420.00',
#   '资金运用情况': '旅游',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 15,
#   'listingId': 124916059,
#   '借款用途': '装修',
#   '借款金额': '14,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '8,000.00',
#   '历史最高负债': '9,143.22',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '网络教育',
#   '工作信息': '私营业主',
#   '年龄': 29,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '男',
#   '成功借款次数': '1次',
#   '成功还款次数': '6次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科',
#   '期限': '6个月',
#   '正常还清次数': '6次',
#   '毕业院校': '西南交通大学',
#   '注册时间': '2017/11/17',
#   '第一次成功借款时间': '2017/11/17',
#   '累计借款金额': '8,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '装修',
#   '还款来源': '经营收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 16,
#   'listingId': 124916107,
#   '借款用途': '日常消费',
#   '借款金额': '3,700',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,700.00',
#   '历史最高负债': '4,228.50',
#   '历史记录': '1次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 28,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '女',
#   '成功借款次数': '2次',
#   '成功还款次数': '13次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '13次',
#   '毕业院校': '无',
#   '注册时间': '2018/03/03',
#   '第一次成功借款时间': '2018/03/03',
#   '累计借款金额': '5,500.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '个人存款',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 17,
#   'listingId': 124916191,
#   '借款用途': '医疗',
#   '借款金额': '700',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '1,500.00',
#   '历史最高负债': '5,033.82',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 19,
#   '征信记录': '暂未提供',
#   '待还金额': '3,743.90',
#   '性别': '男',
#   '成功借款次数': '13次',
#   '成功还款次数': '49次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '47次',
#   '毕业院校': '无',
#   '注册时间': '2017/10/30',
#   '第一次成功借款时间': '2017/11/07',
#   '累计借款金额': '9,900.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '医疗',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '2次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 18,
#   'listingId': 124916416,
#   '借款用途': '日常消费',
#   '借款金额': '7,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '12,000.00',
#   '历史最高负债': '13,477.56',
#   '历史记录': '2次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '1,735.93',
#   '性别': '女',
#   '成功借款次数': '6次',
#   '成功还款次数': '35次',
#   '收入情况': '暂未提供',
#   '文化程度': '本科',
#   '期限': '3个月',
#   '正常还清次数': '21次',
#   '毕业院校': '中央财经大学',
#   '注册时间': '2017/05/12',
#   '第一次成功借款时间': '2017/05/13',
#   '累计借款金额': '30,597.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '11次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 19,
#   'listingId': 124916488,
#   '借款用途': '日常消费',
#   '借款金额': '3,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '3,000.00',
#   '历史最高负债': '3,490.92',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '普通',
#   '工作信息': '暂未提供',
#   '年龄': 31,
#   '征信记录': '暂未提供',
#   '待还金额': '0.00',
#   '性别': '女',
#   '成功借款次数': '2次',
#   '成功还款次数': '7次',
#   '收入情况': '暂未提供',
#   '文化程度': '专科(高职)',
#   '期限': '3个月',
#   '正常还清次数': '6次',
#   '毕业院校': '山西工商职业学院',
#   '注册时间': '2018/03/15',
#   '第一次成功借款时间': '2018/03/15',
#   '累计借款金额': '6,000.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '1次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 20,
#   'listingId': 124916836,
#   '借款用途': '日常消费',
#   '借款金额': '2,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '10,000.00',
#   '历史最高负债': '19,984.07',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 23,
#   '征信记录': '暂未提供',
#   '待还金额': '17,323.89',
#   '性别': '女',
#   '成功借款次数': '14次',
#   '成功还款次数': '100次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '3个月',
#   '正常还清次数': '97次',
#   '毕业院校': '无',
#   '注册时间': '2017/01/16',
#   '第一次成功借款时间': '2017/01/21',
#   '累计借款金额': '39,207.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '3次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 21,
#   'listingId': 124917210,
#   '借款用途': '日常消费',
#   '借款金额': '1,676',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '13,060.00',
#   '历史最高负债': '20,825.01',
#   '历史记录': '0次流标， 0次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '私营业主',
#   '年龄': 27,
#   '征信记录': '暂未提供',
#   '待还金额': '18,652.74',
#   '性别': '女',
#   '成功借款次数': '6次',
#   '成功还款次数': '30次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '30次',
#   '毕业院校': '无',
#   '注册时间': '2017/04/24',
#   '第一次成功借款时间': '2017/04/24',
#   '累计借款金额': '36,451.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '经营收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'},
#  {'Unnamed: 0': 22,
#   'listingId': 124917260,
#   '借款用途': '日常消费',
#   '借款金额': '2,000',
#   '其他事项': '暂无',
#   '协议利率': '20%',
#   '单笔最高借款金额': '5,000.00',
#   '历史最高负债': '12,650.34',
#   '历史记录': '0次流标， 1次撤标， 0次失败',
#   '学习形式': '无',
#   '工作信息': '暂未提供',
#   '年龄': 27,
#   '征信记录': '暂未提供',
#   '待还金额': '10,861.13',
#   '性别': '男',
#   '成功借款次数': '14次',
#   '成功还款次数': '58次',
#   '收入情况': '暂未提供',
#   '文化程度': '无',
#   '期限': '6个月',
#   '正常还清次数': '58次',
#   '毕业院校': '无',
#   '注册时间': '2016/09/05',
#   '第一次成功借款时间': '2016/09/05',
#   '累计借款金额': '38,100.00',
#   '级别': 'B',
#   '网络借贷平台借款余额': '暂未提供',
#   '资金运用情况': '日常消费',
#   '还款来源': '薪资收入',
#   '逾期（0-15天）还清次数': '0次',
#   '逾期（15天以上）还清次数': '0次'}]
