# %%
import pandas as pd

# %%
df = pd.read_csv("invert_detail_back.csv", encoding="utf-8")
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# 5             5             5
# 6             6             6
# 7             7             7
# 8             8             8
# 9             9             9
# 10           10            10
# 11           11            11
# 12           12            12
# 13           13            13
# 14           14            14
# 15           15            15
# 16           16            16
# 17           17            17
# 18           18            18
# 19           19            19
# 20           20            20
# 21           21            21
# 22           22            22
# 23           23            23
# 24           24            24
# 25           25            25
# 26           26            26
# 27           27            27
# 28           28            28
# 29           29            29
# ...

# %%
df_strategy = pd.read_csv("strategylist.csv", encoding="utf-8")
df_strategy
# Out:
#     amount                                          avatarUrl  \
# 0      200  https://jc01.info.user.ppdai.com/ff2d80b70ca94...
# 1      200  https://jc01.info.user.ppdai.com/600bc6ac29ee4...
# 2      200  https://jc01.info.user.ppdai.com/14d28fd4818a4...
# 3      200  https://jc01.info.user.ppdai.com/dc2e1298a3bd4...
# 4      200  https://jc01.info.user.ppdai.com/eea49472f9564...
# 5      200  https://jc01.info.user.ppdai.com/d496785496ed4...
# 6      200  https://jc01.info.user.ppdai.com/dc4cf959aeec4...
# 7      200  https://jc01.info.user.ppdai.com/7c250a53f1064...
# 8      200  https://jc01.info.user.ppdai.com/c5898109af3f4...
# 9      200  https://jc01.info.user.ppdai.com/132170f3c6a54...
# 10     200  https://jc01.info.user.ppdai.com/7dc0577b24b54...
# 11     200  https://jc01.info.user.ppdai.com/2ecb465c30c94...
# 12     200  https://jc01.info.user.ppdai.com/776d3f1aa34b4...
# 13     200  https://jc01.info.user.ppdai.com/50ae275c8a044...
# ...

# %%
df_all = pd.merge(df_strategy, df, on="nickName")

# %%
df_all.to_csv("strategylist_all.csv", encoding="utf-8", index=False)
